# %%
Quantizing an image with KMeans clustering

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy import ndimage
img = ndimage.imread("headshot.jpg")
plt.figure(figsize = (10,7))
plt.imshow(img)

# %%
img.shape
# Out:
# (379L, 337L, 3L)

# %%
x, y, z = img.shape
long_img = img.reshape(x*y, z)
long_img.shape
# Out:
# (127723L, 3L)

# %%
from sklearn import cluster
k_means = cluster.KMeans(n_clusters=5)
k_means.fit(long_img)
centers = k_means.cluster_centers_
centers
# Out:
# array([[ 169.69235986,  189.63274724,  143.75511521],
#        [  45.79271071,   94.56844879,  120.00911162],
#        [ 218.74043562,  202.152748  ,  184.14355039],
#        [  67.51082485,  151.50671141,  201.9408963 ],
#        [ 169.01964615,  123.08399844,   99.6097561 ]])

# %%
labels = k_means.labels_
labels
# Out:
# array([0, 0, 0, ..., 3, 3, 3])

# %%
plt.figure(figsize = (10,7))
plt.imshow(centers[labels].reshape(x, y, z))
